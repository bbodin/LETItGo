# %%
import pandas as pd

df = pd.read_csv("expansion_automotive.log", sep='\s+')

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.set_index(["n","m","KdN"]).plot(y=["TC1","TC2","TC3"])
# Out:
# <AxesSubplot:xlabel='n,m,KdN'>

# %%
df[df["KdN"] == 0].set_index(["n","m","KdN"]).plot(y=["orig", "new", "opt"])
df[df["KdN"] == 1].set_index(["n","m","KdN"]).plot(y=["orig", "new", "opt"])
# Out:
# <AxesSubplot:xlabel='n,m,KdN'>

# %%
df[df["KdN"] == 0].set_index(["n","m","KdN"]).plot(y=["E"])
df[df["KdN"] == 1].set_index(["n","m","KdN"]).plot(y=["E"])
# Out:
# <AxesSubplot:xlabel='n,m,KdN'>
